# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load data

# %%
df = pd.read_excel('Book121.xlsx', sheet_name=0)
df.describe()
# Out:
#                                 Date  Meltdown time(Minutes)       Order No  \
# count                            267              267.000000     261.000000
# mean   2024-05-14 06:49:53.258426880               15.346567  449754.597701
# min              2024-05-07 00:00:00                2.383333  303302.000000
# 25%              2024-05-11 00:00:00               12.683333  303737.000000
# 50%              2024-05-14 00:00:00               14.533333  303872.000000
# 75%              2024-05-18 00:00:00               16.550000  818273.000000
# max              2024-05-22 00:00:00               31.900000  818837.000000
# std                              NaN                5.601419  232413.281788
#
#        PowerCons (Kwh)   Power/min  2nd melt-down time  \
# count       267.000000  267.000000          267.000000
# mean      17233.131086  370.016704           31.320549
# min       14788.000000  258.890000           12.093333
# 25%       16717.500000  360.595000           29.231667
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real

# Drop rows where '1st melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 400].dropna(
    subset=['VCB On Time (min)', 'PowerCons (Kwh)'])

# Plot 1st melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='VCB On Time (min)',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('VCB On Time (min) vs Power Consumption')
plt.xlabel('VCB On Time (min)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 1st melt-down time


def objective_1st(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['VCB On Time (min)'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 1st melt-down time
search_space_1st = [Real(df_cleaned_power['VCB On Time (min)'].min(),
                         df_cleaned_power['VCB On Time (min)'].max(), name='VCB On Time (min)')]

# Run Bayesian Optimization for 1st melt-down time
result_1st = gp_minimize(objective_1st, search_space_1st,
                         n_calls=50, random_state=0)

# Extract the optimal value for 1st melt-down time
optimal_meltdown_time_1st = result_1st.x[0]
print("Optimal VCB On Time (min) (Minutes):", optimal_meltdown_time_1st)

# Visualize the result for 1st melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='VCB On Time (min)', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_1st, color='red', linestyle='--',
            label=f'Optimal 1st Melt-down Time: {optimal_meltdown_time_1st:.2f} min')
plt.title('1st Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal VCB On Time (min) (Minutes): 48.680495639056616

# %%
# Plot 1st melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='VCB On Time (min)',
                y='PowerCons (Kwh)', data=df)
plt.title('VCB On Time (min) vs Power Consumption')
plt.xlabel('VCB On Time (min)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# %%
df['powerconsumption in 1st scrap'].describe()
# Out:
# count    267.000000
# mean      15.346567
# std        5.601419
# min        2.383333
# 25%       12.683333
# 50%       14.533333
# 75%       16.550000
# max       31.900000
# Name: Meltdown time(Minutes), dtype: float64

# %%
df['2nd melt-down time'].describe()
# Out:
# count    267.000000
# mean      31.320549
# std        6.401002
# min       12.093333
# 25%       29.231667
# 50%       32.033333
# 75%       34.420000
# max       48.230000
# Name: 2nd melt-down time, dtype: float64

# %%
df['Power/min'].describe()
# Out:
# count    260.000000
# mean     369.845231
# std       15.465558
# min      258.890000
# 25%      360.497500
# 50%      370.520000
# 75%      380.015000
# max      416.280000
# Name: Power/min, dtype: float64

# %%
df.loc[df['Series'] == 400].shape
# Out:
# (49, 166)

# %%
df.loc[df['Series'] == 400][['PowerCons (Kwh)', 'Meltdown time(Minutes)']].sort_values(by='PowerCons (Kwh)')
# Out:
#      PowerCons (Kwh)  Meltdown time(Minutes)
# 221            17100               16.500000
# 224            17196               16.466667
# 38             17346               20.766667
# 222            17688               15.750000
# 125            17715               11.433333
# 33             17726               25.700000
# 223            17762               15.733333
# 123            17789               16.550000
# 39             17806               12.950000
# 31             17864               12.500000
# 124            17886               13.666667
# 34             18010                4.250000
# 35             18112               13.783333
# 98             18159               14.066667
# 216            18188               11.450000
# 116            18280               12.683333
# 36             18339               16.533333
# 128            18364               12.550000
# 126            18404               14.583333
# 265            18406               17.583333
# ...

# %% [markdown]
# # 200 Series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real

# Drop rows where '1st melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 200].dropna(
    subset=['1st melt-down time', 'PowerCons (Kwh)'])

# Plot 1st melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('1st Melt-down Time vs Power Consumption')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 1st melt-down time


def objective_1st(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['1st melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 1st melt-down time
search_space_1st = [Real(df_cleaned_power['1st melt-down time'].min(),
                         df_cleaned_power['1st melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 1st melt-down time
result_1st = gp_minimize(objective_1st, search_space_1st,
                         n_calls=50, random_state=0)

# Extract the optimal value for 1st melt-down time
optimal_meltdown_time_1st = result_1st.x[0]
print("Optimal 1st Melt-down Time (Minutes):", optimal_meltdown_time_1st)

# Visualize the result for 1st melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_1st, color='red', linestyle='--',
            label=f'Optimal 1st Melt-down Time: {optimal_meltdown_time_1st:.2f} min')
plt.title('1st Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 1st Melt-down Time (Minutes): 13.72900006025614

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where '2nd melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 200].dropna(
    subset=['2nd melt-down time', 'PowerCons (Kwh)'])

# Plot 2nd melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('2nd Melt-down Time vs Power Consumption')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 2nd melt-down time


def objective_2nd(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['2nd melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 2nd melt-down time
search_space_2nd = [Real(df_cleaned_power['2nd melt-down time'].min(),
                         df_cleaned_power['2nd melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 2nd melt-down time
result_2nd = gp_minimize(objective_2nd, search_space_2nd,
                         n_calls=50, random_state=0)

# Extract the optimal value for 2nd melt-down time
optimal_meltdown_time_2nd = result_2nd.x[0]
print("Optimal 2nd Melt-down Time (Minutes):", optimal_meltdown_time_2nd)

# Visualize the result for 2nd melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_2nd, color='red', linestyle='--',
            label=f'Optimal 2nd Melt-down Time: {optimal_meltdown_time_2nd:.2f} min')
plt.title('2nd Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 2nd Melt-down Time (Minutes): 25.983606962533862

# %%
print(df.loc[df['Series'] == 400]['Meltdown time(Minutes)'].describe())
print(df.loc[df['Series'] == 400]['2nd melt-down time'].describe())
# Out:
# count    42.000000
# mean     14.469048
# std       3.091137
# min       4.250000
# 25%      12.791667
# 50%      14.533333
# 75%      16.545833
# max      19.516667
# Name: Meltdown time(Minutes), dtype: float64
# count    42.000000
# mean     35.474524
# std       3.361045
# min      29.010000
# 25%      33.472500
# 50%      35.206667
# 75%      36.937500
# max      45.060000
# Name: 2nd melt-down time, dtype: float64

# %% [markdown]
# # 300 Series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real

# Drop rows where '1st melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 300].dropna(
    subset=['1st melt-down time', 'PowerCons (Kwh)'])

# Plot 1st melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('1st Melt-down Time vs Power Consumption')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 1st melt-down time


def objective_1st(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['1st melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 1st melt-down time
search_space_1st = [Real(df_cleaned_power['1st melt-down time'].min(),
                         df_cleaned_power['1st melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 1st melt-down time
result_1st = gp_minimize(objective_1st, search_space_1st,
                         n_calls=50, random_state=0)

# Extract the optimal value for 1st melt-down time
optimal_meltdown_time_1st = result_1st.x[0]
print("Optimal 1st Melt-down Time (Minutes):", optimal_meltdown_time_1st)

# Visualize the result for 1st melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_1st, color='red', linestyle='--',
            label=f'Optimal 1st Melt-down Time: {optimal_meltdown_time_1st:.2f} min')
plt.title('1st Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 1st Melt-down Time (Minutes): 10.90285911822783

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where '2nd melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 300].dropna(
    subset=['2nd melt-down time', 'PowerCons (Kwh)'])

# Plot 2nd melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('2nd Melt-down Time vs Power Consumption')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 2nd melt-down time


def objective_2nd(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['2nd melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 2nd melt-down time
search_space_2nd = [Real(df_cleaned_power['2nd melt-down time'].min(),
                         df_cleaned_power['2nd melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 2nd melt-down time
result_2nd = gp_minimize(objective_2nd, search_space_2nd,
                         n_calls=50, random_state=0)

# Extract the optimal value for 2nd melt-down time
optimal_meltdown_time_2nd = result_2nd.x[0]
print("Optimal 2nd Melt-down Time (Minutes):", optimal_meltdown_time_2nd)

# Visualize the result for 2nd melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_2nd, color='red', linestyle='--',
            label=f'Optimal 2nd Melt-down Time: {optimal_meltdown_time_2nd:.2f} min')
plt.title('2nd Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 2nd Melt-down Time (Minutes): 32.82949776176913

# %%
df.drop([85,146,133,134,135], inplace=True)

# %%
df[df['Series']==300]['2nd melt-down time'].sort_values()
# Out:
# 144    28.263333
# 79     28.333333
# 143    28.793333
# 131    29.596667
# 141    29.610000
# 82     30.766667
# 86     30.816667
# 105    30.830000
# 7      32.096667
# 2      32.233333
# 142    32.296667
# 8      32.783333
# 81     32.913333
# 145    33.246667
# 80     33.500000
# 140    33.700000
# 3      34.066667
# 4      34.483333
# 1      34.700000
# 87     35.333333
# 130    36.150000
# 132    37.260000
# 83     37.410000
# 5      41.470000
# 6      41.593333
# 84     43.010000
# 88     43.610000
# Name: 2nd melt-down time, dtype: float64

# %% [markdown]
# # 400 Series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real

# Drop rows where '1st melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 400].dropna(
    subset=['1st melt-down time', 'PowerCons (Kwh)'])

# Plot 1st melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('1st Melt-down Time vs Power Consumption')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 1st melt-down time


def objective_1st(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['1st melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 1st melt-down time
search_space_1st = [Real(df_cleaned_power['1st melt-down time'].min(),
                         df_cleaned_power['1st melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 1st melt-down time
result_1st = gp_minimize(objective_1st, search_space_1st,
                         n_calls=50, random_state=0)

# Extract the optimal value for 1st melt-down time
optimal_meltdown_time_1st = result_1st.x[0]
print("Optimal 1st Melt-down Time (Minutes):", optimal_meltdown_time_1st)

# Visualize the result for 1st melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='1st melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_1st, color='red', linestyle='--',
            label=f'Optimal 1st Melt-down Time: {optimal_meltdown_time_1st:.2f} min')
plt.title('1st Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('1st melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 1st Melt-down Time (Minutes): 13.300761171568569

# %%
df.drop([33,38], inplace=True)

# %%
df[df['Series'] == 400]['1st melt-down time'].sort_values(ascending=False)
# Out:
# 41     19.516667
# 219    18.750000
# 102    18.600000
# 266    18.050000
# 265    17.583333
# 104    17.583333
# 30     17.533333
# 103    17.433333
# 101    16.950000
# 217    16.550000
# 123    16.550000
# 36     16.533333
# 221    16.500000
# 224    16.466667
# 37     15.900000
# 222    15.750000
# 223    15.733333
# 220    15.416667
# 114    15.116667
# 118    14.866667
# 126    14.583333
# 99     14.483333
# 120    14.283333
# 117    14.216667
# 98     14.066667
# 127    13.883333
# 35     13.783333
# 124    13.666667
# 115    13.433333
# 39     12.950000
# 119    12.916667
# 32     12.750000
# 116    12.683333
# 128    12.550000
# 31     12.500000
# 40     12.116667
# 129    11.800000
# 216    11.450000
# 125    11.433333
# 100    10.783333
# 218     5.733333
# 34      4.250000
# Name: 1st melt-down time, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where '2nd melt-down time' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 400].dropna(
    subset=['2nd melt-down time', 'PowerCons (Kwh)'])

# Plot 2nd melt-down time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('2nd Melt-down Time vs Power Consumption')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize for 2nd melt-down time


def objective_2nd(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['2nd melt-down time'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space for 2nd melt-down time
search_space_2nd = [Real(df_cleaned_power['2nd melt-down time'].min(),
                         df_cleaned_power['2nd melt-down time'].max(), name='meltdown_time')]

# Run Bayesian Optimization for 2nd melt-down time
result_2nd = gp_minimize(objective_2nd, search_space_2nd,
                         n_calls=50, random_state=0)

# Extract the optimal value for 2nd melt-down time
optimal_meltdown_time_2nd = result_2nd.x[0]
print("Optimal 2nd Melt-down Time (Minutes):", optimal_meltdown_time_2nd)

# Visualize the result for 2nd melt-down time
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2nd melt-down time', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_2nd, color='red', linestyle='--',
            label=f'Optimal 2nd Melt-down Time: {optimal_meltdown_time_2nd:.2f} min')
plt.title('2nd Melt-down Time vs Power Consumption with Optimal Melt-down Time')
plt.xlabel('2nd melt-down time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal 2nd Melt-down Time (Minutes): 33.44043108527396

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Drop rows where 'Meltdown time(Minutes)' or 'Total Delay (min)' is NaN
df_cleaned = df.dropna(subset=['Meltdown time(Minutes)', 'Total Delay (min)'])

# Plot distribution of meltdown times
plt.figure(figsize=(10, 6))
sns.histplot(df_cleaned['Meltdown time(Minutes)'], bins=30, kde=True)
plt.title('Distribution of Meltdown Times')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('Frequency')
plt.show()

# Plot Meltdown time against Total Delay
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)',
                y='Total Delay (min)', data=df_cleaned)
plt.title('Meltdown Time vs Total Delay')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('Total Delay (min)')
plt.show()

# Find the meltdown time with minimum total delay
optimal_meltdown_time = df_cleaned.loc[df_cleaned['Total Delay (min)'].idxmin(
), 'Meltdown time(Minutes)']
optimal_meltdown_time
# Out:
# 12.499999999999996

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where 'Meltdown time(Minutes)' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 200].dropna(
    subset=['Meltdown time(Minutes)', 'PowerCons (Kwh)'])

# Plot Meltdown time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('Meltdown Time vs Power Consumption')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize


def objective(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['Meltdown time(Minutes)'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space
search_space = [Real(df_cleaned_power['Meltdown time(Minutes)'].min(
), df_cleaned_power['Meltdown time(Minutes)'].max(), name='meltdown_time')]

# Run Bayesian Optimization
result = gp_minimize(objective, search_space, n_calls=50, random_state=0)

# Extract the optimal value
optimal_meltdown_time_bayesian = result.x[0]
print("Optimal Meltdown Time (Minutes):", optimal_meltdown_time_bayesian)

# Visualize the result
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_bayesian, color='red', linestyle='--',
            label=f'Optimal Meltdown Time: {optimal_meltdown_time_bayesian:.2f} min')
plt.title('Meltdown Time vs Power Consumption with Optimal Meltdown Time')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal Meltdown Time (Minutes): 13.72900006025614

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where 'Meltdown time(Minutes)' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series'] == 300].dropna(
    subset=['Meltdown time(Minutes)', 'PowerCons (Kwh)'])

# Plot Meltdown time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('Meltdown Time vs Power Consumption')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize


def objective(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['Meltdown time(Minutes)'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space
search_space = [Real(df_cleaned_power['Meltdown time(Minutes)'].min(
), df_cleaned_power['Meltdown time(Minutes)'].max(), name='meltdown_time')]

# Run Bayesian Optimization
result = gp_minimize(objective, search_space, n_calls=50, random_state=0)

# Extract the optimal value
optimal_meltdown_time_bayesian = result.x[0]
print("Optimal Meltdown Time (Minutes):", optimal_meltdown_time_bayesian)

# Visualize the result
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_bayesian, color='red', linestyle='--',
            label=f'Optimal Meltdown Time: {optimal_meltdown_time_bayesian:.2f} min')
plt.title('Meltdown Time vs Power Consumption with Optimal Meltdown Time')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal Meltdown Time (Minutes): 10.90285911822783

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skopt import gp_minimize
from skopt.space import Real


# Drop rows where 'Meltdown time(Minutes)' or 'PowerCons (Kwh)' is NaN
df_cleaned_power = df.loc[df['Series']==400].dropna(
    subset=['Meltdown time(Minutes)', 'PowerCons (Kwh)'])

# Plot Meltdown time against Power Consumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)',
                y='PowerCons (Kwh)', data=df_cleaned_power)
plt.title('Meltdown Time vs Power Consumption')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.show()

# Define the function to minimize


def objective(meltdown_time):
    # Using linear interpolation to estimate power consumption at given meltdown time
    meltdown_time = meltdown_time[0]  # Extract scalar value from array
    power_consumption = np.interp(
        meltdown_time, df_cleaned_power['Meltdown time(Minutes)'], df_cleaned_power['PowerCons (Kwh)'])
    return float(power_consumption)  # Ensure the return value is a scalar


# Define the search space
search_space = [Real(df_cleaned_power['Meltdown time(Minutes)'].min(
), df_cleaned_power['Meltdown time(Minutes)'].max(), name='meltdown_time')]

# Run Bayesian Optimization
result = gp_minimize(objective, search_space, n_calls=50, random_state=0)

# Extract the optimal value
optimal_meltdown_time_bayesian = result.x[0]
print("Optimal Meltdown Time (Minutes):", optimal_meltdown_time_bayesian)

# Visualize the result
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Meltdown time(Minutes)', y='PowerCons (Kwh)',
                data=df_cleaned_power, label='Data Points')
plt.axvline(optimal_meltdown_time_bayesian, color='red', linestyle='--',
            label=f'Optimal Meltdown Time: {optimal_meltdown_time_bayesian:.2f} min')
plt.title('Meltdown Time vs Power Consumption with Optimal Meltdown Time')
plt.xlabel('Meltdown time (Minutes)')
plt.ylabel('PowerCons (Kwh)')
plt.legend()
plt.show()
# Out:
# Optimal Meltdown Time (Minutes): 13.300761171568569

# %%
df.drop([35,32], inplace=True)

# %%
# Out:
# Average Meltdown time for 200 series of steel is : 15.429298245614035
# Average Meltdown time for 300 series of steel is : 15.461458333333347
# Average Meltdown time for 400 series of steel is : 14.86742424242422

# %%
df
# Out:
#           Date  Meltdown time(Minutes)    Heat No  Order No Series  \
# 0   2024-05-07               14.633333  2405J0123  303413.0    200
# 1   2024-05-07               12.500000  2405J0124  303681.0    300
# 2   2024-05-07               15.216667  2405J0125  303636.0    300
# 3   2024-05-07               16.333333  2405J0126  303637.0    300
# 4   2024-05-07               15.866667  2405J0127  303638.0    300
# ..         ...                     ...        ...       ...    ...
# 262 2024-05-21               13.700000  2405J0417  303689.0    200
# 263 2024-05-21               14.233333  2405J0418  303690.0    200
# 264 2024-05-22               15.483333  2405J0419  303652.0    200
# 265 2024-05-22               17.583333  2405J0421  818835.0    400
# 266 2024-05-22               18.050000  2405J0423  818837.0    400
#
#             Grade  No of Charges  Dolomite (Kg)  Lime (D) (Kg)  Lime (I) (Kg)  \
# 0              JT              2            510           1000            NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the slope
slope = 370.016704

# Generate x values
x = np.linspace(0, 35, 5)
# Calculate y values
y = slope * x

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y)

# Add vertical lines
x1 = 13.73
x2 = 15.429
plt.axvline(x=x1, color='r', linestyle='--', label='Optimal meltdown time')
plt.axvline(x=x2, color='b', linestyle='--', label='Average meltdown time of 200 series')

# Calculate y values at x1 and x2
y1 = slope * x1
y2 = slope * x2

# Calculate the difference between the y-values
y_diff = abs(y2 - y1)

# Add a label displaying the y difference
midpoint = (x1+x2)/2
plt.text(midpoint, 8000, f'Power Reduced By {
         y_diff:.2f} KWh', fontsize=12, ha='center', va='bottom', backgroundcolor='white')

# Add labels and title
plt.xlabel('Time(minutes)')
plt.ylabel('Power requirements')
plt.title('AI based EAF control')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the slope
slope = 370.016704

# Generate x values
x = np.linspace(0, 35, 5)
# Calculate y values
y = slope * x

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y)

# Add vertical lines
x1 = 10.9
x2 = 15.461
plt.axvline(x=x1, color='r', linestyle='--', label='Optimal meltdown time')
plt.axvline(x=x2, color='b', linestyle='--',
            label='Average meltdown time of 300 series')

# Calculate y values at x1 and x2
y1 = slope * x1
y2 = slope * x2

# Calculate the difference between the y-values
y_diff = abs(y2 - y1)

# Add a label displaying the y difference
midpoint = (x1+x2)/2
plt.text(midpoint, 8000, f'Power Reduced By {
         y_diff:.2f} KWh', fontsize=12, ha='center', va='bottom', backgroundcolor='white')

# Add labels and title
plt.xlabel('Time(minutes)')
plt.ylabel('Power requirements')
plt.title('AI based EAF control')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the slope
slope = 370.016704

# Generate x values
x = np.linspace(0, 35, 5)
# Calculate y values
y = slope * x

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y)

# Add vertical lines
x1 = 13.30
x2 = 14.86
plt.axvline(x=x1, color='r', linestyle='--', label='Optimal meltdown time')
plt.axvline(x=x2, color='b', linestyle='--',
            label='Average meltdown time of 400 series')

# Calculate y values at x1 and x2
y1 = slope * x1
y2 = slope * x2

# Calculate the difference between the y-values
y_diff = abs(y2 - y1)

# Add a label displaying the y difference
midpoint = (x1+x2)/2
plt.text(midpoint, 8000, f'Power Reduced By {
         y_diff:.2f} KWh', fontsize=12, ha='center', va='bottom', backgroundcolor='white')

# Add labels and title
plt.xlabel('Time(minutes)')
plt.ylabel('Power requirements')
plt.title('AI based EAF control')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
df.loc[df['Series']==200]['M']
